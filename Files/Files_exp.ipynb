# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import pymysql
import sqlalchemy as db
#import MYSQLdb 
pymysql.install_as_MySQLdb()

# %%
def load_data(filename):
    """ Load dataset from filename
    Args:
        filename (string): Path to data
        
    Returns:
        df (DataFrame): Dataset from file
    """
    
    df = pd.read_csv(filename)
    
    
  
    return df

# %%
AK= load_data('AK.csv')
FL=load_data('FL.csv')
TX=load_data('TX.csv')
table_key=load_data('01_TableKey.csv')
column_key =load_data('02_ColumnKey.csv')

# %%
AK.head(3)
# Out:
#    SummaryLevel State  StateFIPS  CountyFIPS  PlaceFIPS  CBSACode  \
# 0            40    AK          2         NaN        NaN       NaN
# 1            40    AK          2         NaN        NaN       NaN
# 2            40    AK          2         NaN        NaN       NaN
#
#    CongressDistrict      GEOID         AreaName  B27001_001  ...  C27018_032  \
# 0               NaN  04000US02           Alaska      712964  ...    323229.0
# 1               NaN  04001US02  Alaska -- Urban      466569  ...    221071.0
# 2               NaN  04043US02  Alaska -- Rural      246395  ...    102158.0
#
#    C27018_033  C27018_034  C27018_035  C27018_036  C27018_037  C27018_038  \
# 0     60109.0      5564.0     54545.0    228218.0     16516.0    211702.0
# 1     42283.0      3743.0     38540.0    155593.0     11787.0    143806.0
# 2     17826.0      1821.0     16005.0     72625.0      4729.0     67896.0
#
#    C27018_039  C27018_040  C27018_041
# 0     34902.0     32497.0      2405.0
# ...

# %%
column_key['ColumnDescription'].unique()
# Out:
# array(['HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE for Civilian Noninstitutionalized Population% Total:',
#        'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE for Civilian Noninstitutionalized Population% Male:',
#        'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE for Civilian Noninstitutionalized Population% Male:% Under 6 years:',
#        'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE for Civilian Noninstitutionalized Population% Male:% Under 6 years:% With health insurance coverage',
#        'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE for Civilian Noninstitutionalized Population% Male:% Under 6 years:% No health insurance coverage',
#        'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE for Civilian Noninstitutionalized Population% Male:% 6 to 17 years:',
#        'HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE for Civilian Noninstitutionalized Population% Male:% 6 to 17 years:% With health insurance coverage',
# ...

# %%
conn = pymysql.connect(host='127.0.0.1',
                       port=3306,
                       user='test', 
                       passwd='test123',  
                       db='covid_data',
                       charset='utf8')

# %%
engine = db.create_engine("mysql+mysqldb://test:test123@localhost:3306/covid_data")

# %%
#AK.to_sql(name='Estados', con=conn)

#AK.to_sql(name='covid_data', con=engine, if_exists = 'append', index=False)
#FL.to_sql(name='covid_data', con=engine, if_exists = 'append', index=False)
#TX.to_sql(name='covid_data', con=engine, if_exists = 'append', index=False)

#table_key.to_sql(name='covid_data', con=engine, if_exists = 'append', index=False)
#column_key.to_sql(name='covid_data', con=engine, if_exists = 'append', index=False)
